# %% [markdown]
# # Avocado Project Evaluation

# %% [markdown]
# **Project Description**
#
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table. Some relevant columns in the dataset:
#
# • Date - The date of the observation\
# • AveragePrice - the average price of a single avocado\
# • type - conventional or organic\
# • year - the year\
# • Region - the city or region of the observation\
# • Total Volume - Total number of avocados sold\
# • 4046 - Total number of avocados with PLU 4046 sold\
# • 4225 - Total number of avocados with PLU 4225 sold\
# • 4770 - Total number of avocados with PLU 4770 sold
#
# **Inspiration /Label**
#
# The dataset can be seen in two angles to find the region and find the average price .
#
# Task: One of Classification and other of Regression
#
# Do both tasks in the same .ipynb file and submit at single file.

# %% [markdown]
# **1. Importing required libraries**

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# **2. Loading csv file into Jupiter notebook for further evaluation**

# %%
data = pd.read_csv('avocado.csv')
data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# We have 18249 rows and 14 columns in our dataset.

# %% [markdown]
# > We will drop first column 'Unnamed' which is irrelevant.

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
# First 5 rows

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
# Last 5 rows

# %%
df.tail()
# Out:
#              Date  AveragePrice  Total Volume     4046     4225    4770  \
# 18244  2018-02-04          1.63      17074.83  2046.96  1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70  3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92  2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    13498.67    13066.82      431.85          0.0  organic  2018
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# ...

# %% [markdown]
# **3. Exploratory Data Analysis**

# %%
# Checking column information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# From above we can see the datatypes of each variable.

# %% [markdown]
# >Region, type, and Date has object as datatype. While rest are int and float.
# We can convert date column datatype to date using datetime function.

# %%
df['Date'] = pd.to_datetime(df.Date)
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Checking for null and dupplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Above heatmap clearly indicates that there are no missing or null values in the dataset. Also, no duplicate value are present in the dataset.

# %%
# Statistical summary

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# Above chart indicates the statistical summary of the dataset.
# >We can see some outliers present in the dataset as there is large gap between 75% and max data.
#
# >Also, mean of almost each column is greater than medium of the data. So data is right skewed and we can see data spread as well as standard daviation is greater than mean in some columns.
#
# > Average price of Avocado is 1.40 USD, minimum is 0.44 USD, and maximum is 3.25 USD

# %% [markdown]
# **4. Visualisation**

# %%
sns.distplot(df["AveragePrice"])
# Out:
# <Axes: xlabel='AveragePrice', ylabel='Density'>

# %% [markdown]
# Mostly the average price of avocado is between 0.5 to 2.5

# %%
sns.barplot(y = df['type'], x = df['AveragePrice'], orient = 'h')
# Out:
# <Axes: xlabel='AveragePrice', ylabel='type'>

# %% [markdown]
# From above barplot, we can see avrage price of avocado is higher than the conventional type. This is obvious as Organic farming is buit expensive and require more time to produce. However, conventional type is less expensive and requires lesser time.

# %%
sns.barplot(x = df['year'], y = df['Total Volume'],hue = df['type'],estimator='mean')
# Out:
# <Axes: xlabel='year', ylabel='Total Volume'>

# %% [markdown]
# As a result, we can see huge difference in volume between conventional and orgnic sales.
# > Abov barplot shows yearly sales and each year we see conventional sales has ouperformed organic sales.
#
# >In 2017, demand for conventional avacoda sales volume remained same before it spiked again in 2018. However, organic sales are remained in the same range over the years due to demand and supply.

# %%
labels = 'Conventional','Organic',
fig, ax = plt.subplots()
ax.pie(df.groupby('type')['Total Volume'].mean(),labels = labels,autopct = '%2.2f%%')
plt.show()

# %% [markdown]
# From above pie chart, we can see 97% volume is of coventional avocado and only 2.8% contributes to Organic.

# %%
# sales distribution for evry region

# %%
df.groupby(['region','year'])['AveragePrice', 'Total Volume'].agg([sum])
# Out:
#                       AveragePrice Total Volume
#                                sum          sum
# region           year
# Albany           2015       160.03   4029896.43
#                  2016       159.53   5264335.59
#                  2017       173.61   5231581.78
#                  2018        34.46   1541986.17
# Atlanta          2015       143.58  23231698.12
# ...                            ...          ...
# West             2018        31.13  92477085.01
# WestTexNewMexico 2015       129.71  41523998.11
#                  2016       129.65  43807431.60
#                  2017       133.28  47389589.29
#                  2018        30.03  11800820.78
#
# [216 rows x 2 columns]

# %%
plt.figure(figsize=(20,20))
plot = 1
for col in df:
    if plot <= 9:
        ax = plt.subplot(3,3,plot)
        sns.distplot(df[col])
        plt.xlabel(col)
    plot+=1
plt.show()

# %% [markdown]
# From above, we can see outliers in the dataet with shap spike.
# >Most of the variables are right skewed.

# %%
sns.countplot(x=df['year'])
plt.show()

# %% [markdown]
# From above, we can see ssales volume was dipped in 2018 and wa lowest compare to other years.

# %%
# Regionwise sales analysis

# %%
plt.figure(figsize=(15,6))
plt.xticks(rotation=90)
sns.barplot(x =df['region'],y =df['AveragePrice'], palette = 'viridis')
# Out:
# <Axes: xlabel='region', ylabel='AveragePrice'>

# %%
plt.figure(figsize = (15,10))
region = df.groupby('region')['Total Volume'].sum().sort_values(ascending=False).reset_index()
sns.barplot(x= region['Total Volume'], y= region['region'], palette='rocket')
# Out:
# <Axes: xlabel='Total Volume', ylabel='region'>

# %% [markdown]
# From above we can see, sales volume in West, California, and south central was maximum and Syracuse contributed to minimum sales volume.

# %% [markdown]
# We have some categorical features present in the dataset. So e will need to encode them using Label Encoder.

# %%
# Transforming features with label encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['region'] = le.fit_transform(df['region'])
df['type'] = le.fit_transform(df['type'])
df
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0     2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1     2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2     2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3     2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4     2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# ...

# %% [markdown]
# Now we can see our features are successfuly transformed into numerical form.

# %%
# checking for outliers

# %%
plt.figure(figsize = (15,10))
df.plot(kind= 'box', subplots = True, layout = (4,3))
plt.tight_layout()

# %% [markdown]
# We can see so many outliers present in the dataset and we will need to remove it for our model to pedict the result accurately.

# %%
# removing outliers

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.drop(['Date','year'], axis=1, inplace = True)

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(df))

# %%
threshold = 3
print(np.where(z>3))
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
dfn = df[(z<3).all(axis=1)]

# %%
dfn
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  region
# ...

# %%
df.shape
# Out:
# (18249, 11)

# %%
dfn.shape
# Out:
# (17651, 11)

# %% [markdown]
# We can see outliers has been removed from our dataset as number of rows are reduced from 18249 to 17651.

# %%
# Checking for correlation

# %%
sns.heatmap(dfn.corr(), annot = True, cmap = 'magma')
# Out:
# <Axes: >

# %% [markdown]
# > 4046,4225,4770 feature are Total avacado sold under particular grade. As we do not have any price data according each grade, so we will drop them as we dont require it for our model.

# %%
dfn.drop(columns=['4046','4225','4770','Total Bags','region'],axis=1, inplace=True)

# %%
dfn
# Out:
#        AveragePrice  Total Volume  Small Bags  Large Bags  XLarge Bags  type
# 0              1.33      64236.62     8603.62       93.25          0.0     0
# 1              1.35      54876.98     9408.07       97.49          0.0     0
# 2              0.93     118220.22     8042.21      103.14          0.0     0
# 3              1.08      78992.15     5677.40      133.76          0.0     0
# 4              1.28      51039.60     5986.26      197.69          0.0     0
# ...             ...           ...         ...         ...          ...   ...
# 18244          1.63      17074.83    13066.82      431.85          0.0     1
# 18245          1.71      13888.04     8940.04      324.80          0.0     1
# 18246          1.87      13766.76     9351.80       42.31          0.0     1
# 18247          1.93      16205.22    10919.54       50.00          0.0     1
# 18248          1.62      17489.58    11988.14       26.01          0.0     1
#
# [17651 rows x 6 columns]

# %%
#Checking Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif= pd.DataFrame()
vif['Features']= dfn.columns
vif['VIF']= [variance_inflation_factor(dfn.values,i) for i in range(dfn.shape[1])]
vif
# Out:
#        Features       VIF
# 0  AveragePrice  3.747245
# 1  Total Volume  7.584622
# 2    Small Bags  7.692734
# 3    Large Bags  1.945974
# 4   XLarge Bags  1.693126
# 5          type  3.358876

# %% [markdown]
# Removing column to address multicollinearity is not good idea. So we can scale the data and the apply PCA technic.

# %%
for col in dfn.columns:
    if dfn.skew().loc[col]>0.55:
        dfn[col]=np.log1p(dfn[col])

# %%
#Splitting data into x and y variable

# %%
x = dfn.drop('AveragePrice', axis=1)
y = dfn['AveragePrice']

# %%
# Scaling the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
xs = sc.fit_transform(x)

# %%
xs
# Out:
# array([[-0.06196232, -0.21578885, -0.64825387, -0.6273191 , -1.01904715],
#        [-0.13430157, -0.17958983, -0.6365202 , -0.6273191 , -1.01904715],
#        [ 0.21823548, -0.24311628, -0.62164622, -0.6273191 , -1.01904715],
#        ...,
#        [-0.76950251, -0.18201931, -0.85559137, -0.6273191 ,  0.98130886],
#        [-0.69459605, -0.11925277, -0.81200971, -0.6273191 ,  0.98130886],
#        [-0.65956156, -0.08144136, -0.98149671, -0.6273191 ,  0.98130886]])

# %% [markdown]
# **5. Building Machine Learning Model**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import Lasso, Ridge, ElasticNet

# %%
x_train,x_test,y_train,y_test = train_test_split(xs,y,test_size = .30, random_state = 42)

# %%
x_train.shape
# Out:
# (12355, 5)

# %%
x_test.shape
# Out:
# (5296, 5)

# %%
lm = LinearRegression()
ls = Lasso(alpha = 0.01)
rg = Ridge(alpha = 0.01)
en = ElasticNet(alpha = 0.01)
knr = KNeighborsRegressor()
dtr = DecisionTreeRegressor()
svr = SVR()
rfr = RandomForestRegressor()
abr = AdaBoostRegressor()
gbr = GradientBoostingRegressor()

# %%
model = [lm,ls,rg,en,knr,dtr,svr,rfr,abr,gbr]

# %%
print('----------------Machine Learning Model Performance------------------\n')
def mod():
    for i in model:
        print(i,'\n')
        i.fit(x_train,y_train)
        print('Score:', i.score(x_train, y_train))
        pred = i.predict(x_test)
    
        print('Mean squared Error:', mean_squared_error(pred, y_test))
        print('Mean absolute Error:', mean_absolute_error(pred, y_test),'\n')
        print('r2_score', r2_score(pred, y_test))
        print('Cross Validation Score for', i,':')
        score = cross_val_score(i,xs,y, cv=5)
        print('Score:', score.mean())
        print('\n********************************************************************\n')
mod()
# Out:
# ----------------Machine Learning Model Performance------------------
#
# LinearRegression()
#
# Score: 0.4249547588266054
# Mean squared Error: 0.08535437986748526
# Mean absolute Error: 0.2310825833332486
#
# r2_score -0.35034622924158043
# Cross Validation Score for LinearRegression() :
# Score: -0.00427353759117075
#
# ********************************************************************
#
# Lasso(alpha=0.01)
#
# Score: 0.4196366407310804
# Mean squared Error: 0.0864840634554726
# Mean absolute Error: 0.23233688928612728
#
# r2_score -0.5161934010415266
# Cross Validation Score for Lasso(alpha=0.01) :
# Score: -0.04469531575078143
#
# ********************************************************************
#
# Ridge(alpha=0.01)
#
# Score: 0.424954758826132
# Mean squared Error: 0.08535437914121381
# Mean absolute Error: 0.23108258551311167
#
# r2_score -0.3503477787983942
# Cross Validation Score for Ridge(alpha=0.01) :
# Score: -0.004273675342587313
#
# ...

# %% [markdown]
# **Hyper Parameter Tuning**

# %%
parameter = {'n_estimators':[30,60,80],'max_depth': [10,20,40],
             'min_samples_leaf':[5,10],'criterion':['mse','mae']}

# %%
gc = GridSearchCV(RandomForestRegressor(),parameter,cv=5,n_jobs = -1,verbose = 3)

# %%
gc.fit(x_train,y_train)

# %% [markdown]
# Fitting 5 folds for each of 36 candidates, totalling 180 fits

# %% [markdown]
# Based on r2_score RandomForestRegressor is our best model

# %%
best_mod =  RandomForestRegressor(n_estimators=72 ,criterion = 'friedman_mse', max_depth= 20, max_features = 'auto',
             min_samples_leaf = 5, min_samples_split = 10)
best_mod.fit(x_train,y_train)
pred=best_mod.predict(x_test)                                     
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,pred)))
print(r2_score(y_test,pred))
# Out:
# Mean absolute error : 0.18473029643462655
# Mean squared error : 0.05907911189861113
# Root Mean Squared Error: 0.24306195074221537
# 0.6035152899260338

# %%
# Saving the model
import joblib

# %%
joblib.dump(best_mod, 'bmodel.obj')
bm = joblib.load('bmodel.obj')

# %%
bm.predict(x_test)
# Out:
# array([1.3620482 , 1.59335783, 1.21917764, ..., 1.66999599, 1.54698283,
#        1.11022444])
