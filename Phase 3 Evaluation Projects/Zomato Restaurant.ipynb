# %% [markdown]
# # Zomato Restaurant

# %% [markdown]
# **Project Description**
#
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# **Data Storage:**
#
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
# • Country code
# • Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world\
# • Restaurant Name: Name of the restaurant\
# • Country Code: Country in which restaurant is located\
# • City: City in which restaurant is located\
# • Address: Address of the restaurant\
# • Locality: Location in the city\
# • Locality Verbose: Detailed description of the locality\
# • Longitude: Longitude coordinate of the restaurant&#39;s location\
# • Latitude: Latitude coordinate of the restaurant&#39;s location\
# • Cuisines: Cuisines offered by the restaurant\
# • Average Cost for two: Cost for two people in different currencies ��\
# • Currency: Currency of the country\
# • Has Table booking: yes/no\
# • Has Online delivery: yes/ no\
# • Is delivering: yes/ no\
# • Switch to order menu: yes/no\
# • Price range: range of price of food\
# • Aggregate Rating: Average rating out of 5\
# • Rating color: depending upon the average rating color\
# • Rating text: text on the basis of rating of rating\
# • Votes: Number of ratings casted by people
#
# **Problem statement : In this dataset predict 2 things –**
# 1) Average Cost for two
# 2) Price range
#
#
# Hint : Use pandas methods to combine all the datasets and then start working on this project.
#
# Dataset Link-
# •	https://github.com/FlipRoboTechnologies/ML_-Datasets/blob/main/Z_Restaurant/Country-Code.xlsx
#
# •	https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv

# %% [markdown]
# **1. Importing all required libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **2. Importing data from csv file and loaded into Jupyter notebook for further processing.**

# %%
data = pd.read_csv('zomato.csv', error_bad_lines=False, encoding='latin-1')
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1 = pd.DataFrame(data)
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# Importing 2nd excel file which contain country codes

# %%
df2 = pd.read_excel('Country-Code.xlsx')
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
# We need to merge both files into one to reflect country name in place of codes

# %%
df = pd.merge(df1,df2)
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
# We have successfully merge both files. We can drop country code column as we don't need it.

# %%
df.drop(['Country Code'],axis=1, inplace=True)

# %%
# Dropping unnecessary columns

# %%
df.drop(['Restaurant ID','Address', 'Locality Verbose', 'Longitude', 'Latitude', 'Switch to order menu'], axis=1, inplace =True)

# %%
# Number of rows and columns

# %%
df.shape
# Out:
# (9551, 15)

# %% [markdown]
# There are 9551 rows and 15 columns present in the dataset.

# %% [markdown]
# **3. Exploratory Data Analysis (EDA)**

# %%
# First 5 rows

# %%
df.head()
# Out:
#           Restaurant Name              City  \
# 0        Le Petit Souffle       Makati City
# 1        Izakaya Kikufuji       Makati City
# 2  Heat - Edsa Shangri-La  Mandaluyong City
# 3                    Ooma  Mandaluyong City
# 4             Sambo Kojin  Mandaluyong City
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                            Cuisines  Average Cost for two          Currency  \
# 0        French, Japanese, Desserts                  1100  Botswana Pula(P)
# 1                          Japanese                  1200  Botswana Pula(P)
# 2  Seafood, Asian, Filipino, Indian                  4000  Botswana Pula(P)
# 3                   Japanese, Sushi                  1500  Botswana Pula(P)
# ...

# %%
# Last 5 rows

# %%
df.tail()
# Out:
#                Restaurant Name       City     Locality  \
# 9546              NamlÛ± Gurme  ÛÁstanbul     Karakí_y
# 9547             Ceviz AÛôacÛ±  ÛÁstanbul    Koôuyolu
# 9548                     Huqqa  ÛÁstanbul  Kuruí_eôme
# 9549              Aôôk Kahve  ÛÁstanbul  Kuruí_eôme
# 9550  Walter's Coffee Roastery  ÛÁstanbul         Moda
#
#                              Cuisines  Average Cost for two          Currency  \
# 9546                          Turkish                    80  Turkish Lira(TL)
# 9547  World Cuisine, Patisserie, Cafe                   105  Turkish Lira(TL)
# 9548           Italian, World Cuisine                   170  Turkish Lira(TL)
# 9549                  Restaurant Cafe                   120  Turkish Lira(TL)
# 9550                             Cafe                    55  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  Price range  \
# 9546                No                  No                No            3
# ...

# %%
# Checking for duplicate values

# %%
df.duplicated().sum()
# Out:
# 3

# %% [markdown]
# There are no duplicate values present in the dataset.

# %%
# Checking for white spaces, NA values

# %%
df.isin([' ','NA','-']).sum()
# Out:
# Restaurant Name         0
# City                    0
# Locality                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# So we don't have any whitespaces in the Dataset.

# %%
# Checking column information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       9551 non-null   object
#  1   City                  9551 non-null   object
#  2   Locality              9551 non-null   object
#  3   Cuisines              9542 non-null   object
#  4   Average Cost for two  9551 non-null   int64
#  5   Currency              9551 non-null   object
#  6   Has Table booking     9551 non-null   object
#  7   Has Online delivery   9551 non-null   object
#  8   Is delivering now     9551 non-null   object
#  9   Price range           9551 non-null   int64
#  10  Aggregate rating      9551 non-null   float64
#  11  Rating color          9551 non-null   object
#  12  Rating text           9551 non-null   object
#  13  Votes                 9551 non-null   int64
#  14  Country               9551 non-null   object
# ...

# %% [markdown]
# Out of 21 columns,
# * We have 14 columns with categorical data (object type)
# * 7 Columns are having numerical data

# %%
# Checking for Null values

# %%
df.isnull().sum()
# Out:
# Restaurant Name         0
# City                    0
# Locality                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
sns.heatmap(df.isnull().T)
# Out:
# <Axes: >

# %% [markdown]
# We have only 9 null value present in the dataset in cusines column.

# %%
df['Cuisines'].dtypes
# Out:
# dtype('O')

# %%
# Filling null values with mode of the column as our variable is of object type

# %%
df['Cuisines'] = df['Cuisines'].fillna(df['Cuisines'].mode()[0])

# %%
# Verifyig null values again

# %%
df.isnull().sum()
# Out:
# Restaurant Name         0
# City                    0
# Locality                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# We have removed null values

# %%
# Checking unique cuisines

# %%
df['Cuisines'].unique()
# Out:
# array(['French, Japanese, Desserts', 'Japanese',
#        'Seafood, Asian, Filipino, Indian', ..., 'Burger, Izgara',
#        'World Cuisine, Patisserie, Cafe', 'Italian, World Cuisine'],
#       dtype=object)

# %%
df['Cuisines']
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9551, dtype: object

# %%
# Statistical summary

# %%
df.describe()
# Out:
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
df.describe(exclude=[np.number])
# Out:
#         Restaurant Name       City         Locality      Cuisines  \
# count              9551       9551             9551          9551
# unique             7446        141             1208          1825
# top     Cafe Coffee Day  New Delhi  Connaught Place  North Indian
# freq                 83       5473              122           945
#
#                   Currency Has Table booking Has Online delivery  \
# count                 9551              9551                9551
# unique                  12                 2                   2
# top     Indian Rupees(Rs.)                No                  No
# freq                  8652              8393                7100
#
#        Is delivering now Rating color Rating text Country
# count               9551         9551        9551    9551
# unique                 2            6           6      15
# top                   No       Orange     Average   India
# freq                9517         3737        3737    8652

# %% [markdown]
# **3. Data Visualisation**

# %% [markdown]
# **Target variables:**
# 1. Average cost for two
# 2. Price range

# %%
sns.distplot(df['Average Cost for two'])
# Out:
# <Axes: xlabel='Average Cost for two', ylabel='Density'>

# %%
df['Average Cost for two'].skew()
# Out:
# 35.477914900871276

# %% [markdown]
# As we see from above chart, our target variable 'Average Cost for two' is right skeed and hence the outliers are present in the dataset.

# %%
# Checking price range feature

# %%
df['Price range'].value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %%
df['Price range'].value_counts().plot.pie(autopct = '%2.1f%%')
# Out:
# <Axes: ylabel='Price range'>

# %% [markdown]
# From above pie chart,
#
# * 46.5% data fall within price range 1
# * 32.6% in range 2
# * 14.7% in range 3
# * 6.1% in range 4

# %% [markdown]
# This makes our target variable imbalanced and we will need to reciy this later for our model.

# %%
# Seperating numerical and categorical variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       9551 non-null   object
#  1   City                  9551 non-null   object
#  2   Locality              9551 non-null   object
#  3   Cuisines              9551 non-null   object
#  4   Average Cost for two  9551 non-null   int64
#  5   Currency              9551 non-null   object
#  6   Has Table booking     9551 non-null   object
#  7   Has Online delivery   9551 non-null   object
#  8   Is delivering now     9551 non-null   object
#  9   Price range           9551 non-null   int64
#  10  Aggregate rating      9551 non-null   float64
#  11  Rating color          9551 non-null   object
#  12  Rating text           9551 non-null   object
#  13  Votes                 9551 non-null   int64
#  14  Country               9551 non-null   object
# ...

# %%
cat = ['Restaurant Name', 'City', 'Locality', 'Cuisines', 'Currency',
      'Has Table booking', 'Has Online delivery', 'Is delivering now', 
      'Rating color', 'Rating text', 'Country']

num = ['Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
# Analysing categorical feature and their subcategories

# %%
for i in cat:
    print(i)
    print(df[i].value_counts())
    print('***********************************************************')
# Out:
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
# ***********************************************************
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
#                 ...
# Huskisson          1
# Panchkula          1
# Forrest            1
# Flaxton            1
# Chatham-Kent       1
# Name: City, Length: 141, dtype: int64
# ***********************************************************
# Locality
# Connaught Place                                122
# Rajouri Garden                                  99
# ...

# %%
# frequency of first 10 City

# %%
plt.figure(figsize = (15,10))
col = 'City'
df_counts = df[col].value_counts()
ax = sns.barplot(x=df_counts[:10].index, y=df_counts[:10].values, palette='magma')

# %% [markdown]
# Majority of observation comes from Delhi.

# %%
# frequency of first 10 Currency

# %%
plt.figure(figsize = (15,10))
col = 'Currency'
df_counts = df[col].value_counts()
ax = sns.barplot(x=df_counts[:10].index, y=df_counts[:10].values, palette='magma')

# %% [markdown]
# The dominant currency is the Indian Rupee (Rs.)

# %%
# Visualize the frequency of Has Table booking

# %%
col = 'Has Table booking'
plt.figure(figsize=(10, 5))
df_counts = df[col].value_counts()

ax = sns.barplot(x=df_counts.index, y=df_counts.values, palette='magma')

# %% [markdown]
# Very small perecentage of booking we can see from above chart.

# %%
# Visualize the frequency of Has Online delivery

# %%
col = 'Has Online delivery'
plt.figure(figsize=(10, 5))
df_counts = df[col].value_counts()

ax = sns.barplot(x=df_counts.index, y=df_counts.values, palette='magma')

# %% [markdown]
# Less than 50% of data shows online delivery.

# %%
# Visualize the frequency of Is delivering now

# %%
col = 'Is delivering now'
plt.figure(figsize=(10, 5))
df_counts = df[col].value_counts()

ax = sns.barplot(x=df_counts.index, y=df_counts.values, palette='magma')

# %% [markdown]
# Only small percentage of data shows delivering now.

# %%
# Visualize the frequency of Rating color

# %%
col = 'Rating color'
plt.figure(figsize=(10, 5))
df_counts = df[col].value_counts()

ax = sns.barplot(x=df_counts.index, y=df_counts.values, palette='magma')

# %% [markdown]
# Most of the ratings are labeled as 'Orange'.

# %%
# Visualize the frequency of Rating text

# %%
col = 'Rating text'
plt.figure(figsize=(10, 5))
df_counts = df[col].value_counts()

ax = sns.barplot(x=df_counts.index, y=df_counts.values, palette='magma')

# %% [markdown]
# Most of the ratings are labeled as 'Average'

# %%
# Visualize the frequency of Country

# %%
col = 'Country'
plt.figure(figsize=(10, 5))
df_counts = df[col].value_counts()
ax = sns.barplot(x=df_counts.index, y=df_counts.values, palette='viridis')
plt.tight_layout()

# %% [markdown]
# India is dominating among other countries

# %%
# Distribution for Numerical columns

# %%
plot = 1
for i in df[num]:
    if plot <= 4:
        ax = plt.subplot(2,2,plot)
        sns.distplot(df[num][i])
    plot += 1
plt.tight_layout()

# %%
# Converting categorcial data into numerical form using Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for i in cat:
    df[i] = le.fit_transform(df[i])

# %%
df.head()
# Out:
#    Restaurant Name  City  Locality  Cuisines  Average Cost for two  Currency  \
# 0             3749    73       171       920                  1100         0
# 1             3173    73       593      1111                  1200         0
# 2             2897    75       308      1671                  4000         0
# 3             4707    75       862      1126                  1500         0
# 4             5523    75       862      1122                  1500         0
#
#    Has Table booking  Has Online delivery  Is delivering now  Price range  \
# 0                  1                    0                  0            3
# 1                  1                    0                  0            3
# 2                  1                    0                  0            4
# 3                  0                    0                  0            4
# 4                  1                    0                  0            4
#
# ...

# %%
# Outliers detecting and removal

# %%
plt.figure(figsize = (15,10))
plot = 1
for i in df:
    if plot <= 21:
        ax = plt.subplot(7,3,plot)
        sns.boxplot(df[i], orient = 'h', color = 'g')
        plt.xlabel(i)
    plot += 1
plt.tight_layout()

# %% [markdown]
# From above boxplot, we can see there are some outliers present in the dataset and we will need to remove it

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(df))
z
# Out:
#       Restaurant Name      City  Locality  Cuisines  Average Cost for two  \
# 0            0.044706  0.228533  1.542278  0.135100              0.006154
# 1            0.224101  0.228533  0.206201  0.236387              0.000049
# 2            0.352904  0.142317  1.108528  1.325565              0.173743
# 3            0.491783  0.142317  0.645470  0.265562              0.018659
# 4            0.872592  0.142317  0.645470  0.257782              0.018659
# ...               ...       ...       ...       ...                   ...
# 9546         0.368580  2.659685  0.446821  1.601750              0.069428
# 9547         1.093055  2.659685  0.336009  1.623144              0.067878
# 9548         0.272635  2.659685  0.329677  0.234442              0.063845
# 9549         1.465464  2.659685  0.329677  1.298336              0.066947
# 9550         1.673878  2.659685  0.037586  1.280682              0.070979
#
#       Currency  Has Table booking  Has Online delivery  Is delivering now  \
# ...

# %%
threshold = 3
print(np.where(z>3))
# Out:
# (array([   0,    1,    2, ..., 9548, 9549, 9550]), array([5, 5, 5, ..., 5, 5, 5]))

# %%
dfn = df[(z<3).all(axis=1)]
dfn.head()
# Out:
#      Restaurant Name  City  Locality  Cuisines  Average Cost for two  \
# 517             6320    12        93      1270                    20
# 518              967    15       111      1619                    20
# 519             6608    37       282       620                     7
# 520             6431    41       302       331                    20
# 521             2372    45       328      1793                    30
#
#      Currency  Has Table booking  Has Online delivery  Is delivering now  \
# 517         2                  0                    0                  0
# 518         2                  0                    0                  0
# 519         2                  0                    0                  0
# 520         2                  0                    0                  0
# 521         2                  0                    0                  0
#
#      Price range  Aggregate rating  Rating color  Rating text  Votes  Country
# ...

# %%
df.shape
# Out:
# (9551, 15)

# %%
dfn.shape
# Out:
# (8474, 15)

# %% [markdown]
# We have successfully removed outliers from our dataset.

# %%
# Checking for skewness

# %%
plt.figure(figsize = (15,10))
plot = 1
for i in num:
    if plot <= 21:
        ax = plt.subplot(2,2, plot)
        sns.distplot(df[i], color = 'r')
        plt.xlabel(i)
    plot += 1
plt.tight_layout()

# %%
dfn[num].skew()
# Out:
# Average Cost for two    3.707455
# Price range             1.045083
# Aggregate rating       -0.865841
# Votes                   3.702993
# dtype: float64

# %%
dfn['Average Cost for two'] = np.cbrt(dfn['Average Cost for two'])
dfn['Votes'] = np.cbrt(dfn['Votes'])

# %%
dfn.head()
# Out:
#      Restaurant Name  City  Locality  Cuisines  Average Cost for two  \
# 517             6320    12        93      1270              2.714418
# 518              967    15       111      1619              2.714418
# 519             6608    37       282       620              1.912931
# 520             6431    41       302       331              2.714418
# 521             2372    45       328      1793              3.107233
#
#      Currency  Has Table booking  Has Online delivery  Is delivering now  \
# 517         2                  0                    0                  0
# 518         2                  0                    0                  0
# 519         2                  0                    0                  0
# 520         2                  0                    0                  0
# 521         2                  0                    0                  0
#
#      Price range  Aggregate rating  Rating color  Rating text     Votes  \
# ...

# %%
# Checking for correlation

# %%
df.corr()
# Out:
#                       Restaurant Name      City  Locality  Cuisines  \
# Restaurant Name              1.000000 -0.001399  0.004322  0.051679
# City                        -0.001399  1.000000  0.096444  0.026614
# Locality                     0.004322  0.096444  1.000000  0.006993
# Cuisines                     0.051679  0.026614  0.006993  1.000000
# Average Cost for two         0.019241 -0.028838 -0.012136  0.005831
# Currency                     0.009669 -0.071996  0.023723  0.068912
# Has Table booking            0.041173 -0.003762 -0.065594  0.050639
# Has Online delivery          0.028082  0.012723 -0.030993 -0.016639
# Is delivering now            0.011984 -0.014039 -0.007299  0.007773
# Price range                  0.061275 -0.105759 -0.114459 -0.005350
# Aggregate rating             0.029367 -0.132163 -0.174336 -0.080331
# Rating color                -0.007311  0.110887  0.036831 -0.016228
# Rating text                  0.012131 -0.098985 -0.036969 -0.079979
# ...

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(),annot = True, cmap='Blues')
# Out:
# <Axes: >

# %%
# Sperating data into x and y variables for average price of 2

# %%
x = df.drop(['Average Cost for two'], axis=1)

# %%
y = df['Average Cost for two']

# %%
x2 = df.drop(['Price range'], axis=1)
y2 = df['Price range']

# %%
x.shape
# Out:
# (9551, 14)

# %%
y.shape
# Out:
# (9551,)

# %%
# Scaling the data unsing Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x.head()
# Out:
#    Restaurant Name      City  Locality  Cuisines  Currency  Has Table booking  \
# 0         0.044706 -0.228533 -1.542278 -0.135100 -4.351046           2.692181
# 1        -0.224101 -0.228533 -0.206201  0.236387 -4.351046           2.692181
# 2        -0.352904 -0.142317 -1.108528  1.325565 -4.351046           2.692181
# 3         0.491783 -0.142317  0.645470  0.265562 -4.351046          -0.371446
# 4         0.872592 -0.142317  0.645470  0.257782 -4.351046           2.692181
#
#    Has Online delivery  Is delivering now  Price range  Aggregate rating  \
# 0            -0.587547          -0.059771     1.319803          1.407131
# 1            -0.587547          -0.059771     1.319803          1.209281
# 2            -0.587547          -0.059771     2.424090          1.143331
# 3            -0.587547          -0.059771     2.424090          1.473081
# 4            -0.587547          -0.059771     2.424090          1.407131
#
#    Rating color  Rating text     Votes   Country
# ...

# %%
scaler2 = StandardScaler()

# Scaling data 
x2 = pd.DataFrame(scaler2.fit_transform(x2), columns = x2.columns)

# %%
# Checking for Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['Features'] = x.columns
vif['VIF values'] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]

# %%
vif
# Out:
#                Features  VIF values
# 0       Restaurant Name    1.007903
# 1                  City    1.069024
# 2              Locality    1.051068
# 3              Cuisines    1.039514
# 4              Currency    1.041992
# 5     Has Table booking    1.399658
# 6   Has Online delivery    1.127266
# 7     Is delivering now    1.013067
# 8           Price range    1.781698
# 9      Aggregate rating    1.809132
# 10         Rating color    1.217058
# 11          Rating text    1.311651
# 12                Votes    1.246770
# 13              Country    1.288553

# %%
# Checking for imbalance dataset

# %%
from imblearn.over_sampling import SMOTE

# %%
SM = SMOTE()

# %%
X,Y = SM.fit_resample(x2, y2)

# %% [markdown]
# **5. Machine Learning Model**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =.30, random_state = 42)

# %%
x_train.shape
# Out:
# (6685, 14)

# %%
x_test.shape
# Out:
# (2866, 14)

# %%
lm = LinearRegression()
ls = Lasso(alpha = 0.001)
rd = Ridge(alpha = 0.001)
en = ElasticNet(alpha = 0.001)
dtr = DecisionTreeRegressor()
knr = KNeighborsRegressor()
svr = SVR()
rfr = RandomForestRegressor() 
gbr = GradientBoostingRegressor()

# %%
model = [lm, ls, rd, en, dtr, knr, svr, rfr, gbr]

# %%
print('----------------Machine Learning Model Performance------------------\n')
def mod():
    for i in model:
        print(i,'\n')
        i.fit(x_train,y_train)
        print('Score:', i.score(x_train, y_train))
        pred = i.predict(x_test)
    
        print('mean_squared_error:', mean_squared_error(pred, y_test))
        print('mean_absolute_error:', mean_absolute_error(y_test, pred))
        print('r2_score:', r2_score(y_test, pred))
        score = cross_val_score(i,x,y, cv=5)
        print('Cross Validation Score for', i,':',score.mean())
        print('\n********************************************************************\n')
mod()
# Out:
# ----------------Machine Learning Model Performance------------------
#
# LinearRegression()
#
# Score: 0.01638625398114335
# mean_squared_error: 267341837.3518783
# mean_absolute_error: 1767.104668906082
# r2_score: 0.009190110373142324
# Cross Validation Score for LinearRegression() : -44.107545003767385
#
# ********************************************************************
#
# Lasso(alpha=0.001)
#
# Score: 0.016386253981075183
# mean_squared_error: 267341833.17518342
# mean_absolute_error: 1767.102297914882
# r2_score: 0.009190125852614695
# Cross Validation Score for Lasso(alpha=0.001) : -44.107025682739106
#
# ********************************************************************
#
# Ridge(alpha=0.001)
#
# Score: 0.016386253981142684
# mean_squared_error: 267341836.8800203
# mean_absolute_error: 1767.1044472338153
# r2_score: 0.009190112121920446
# Cross Validation Score for Ridge(alpha=0.001) : -44.10736560884298
#
# ...
